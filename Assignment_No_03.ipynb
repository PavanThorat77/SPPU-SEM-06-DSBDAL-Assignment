# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Employee.xls')

# %%
df = df[['Age','Department','EducationField','EmployeeNumber','Gender','JobRole','MonthlyIncome','PercentSalaryHike']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                412 non-null    int64
#  1   Department         412 non-null    object
#  2   EducationField     412 non-null    object
#  3   EmployeeNumber     412 non-null    int64
#  4   Gender             412 non-null    object
#  5   JobRole            412 non-null    object
#  6   MonthlyIncome      412 non-null    int64
#  7   PercentSalaryHike  412 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 25.9+ KB

# %%
df
# Out:
#      Age              Department EducationField  EmployeeNumber  Gender  \
# 0     34                   Sales        Medical            1489  Female
# 1     35                   Sales  Life Sciences            1492    Male
# 2     24  Research & Development        Medical            1494    Male
# 3     24                   Sales  Life Sciences            1495  Female
# 4     44  Research & Development        Medical            1496    Male
# ..   ...                     ...            ...             ...     ...
# 407   36  Research & Development        Medical            2061    Male
# 408   39  Research & Development        Medical            2062    Male
# 409   27  Research & Development  Life Sciences            2064    Male
# 410   49                   Sales        Medical            2065    Male
# 411   34  Research & Development        Medical            2068    Male
#
#                        JobRole  MonthlyIncome  PercentSalaryHike
# ...

# %%
df.dtypes
# Out:
# Age                   int64
# Department           object
# EducationField       object
# EmployeeNumber        int64
# Gender               object
# JobRole              object
# MonthlyIncome         int64
# PercentSalaryHike     int64
# dtype: object

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.describe()
# Out:
#               Age  EmployeeNumber  MonthlyIncome  PercentSalaryHike
# count  412.000000      412.000000     412.000000         412.000000
# mean    36.584951     1777.565534    6187.036408          15.347087
# std      8.389257      166.285256    4346.817107           3.708794
# min     18.000000     1489.000000    1081.000000          11.000000
# 25%     31.000000     1637.250000    2951.000000          12.000000
# 50%     35.500000     1769.000000    4973.000000          14.000000
# 75%     42.000000     1929.500000    7458.250000          18.000000
# max     60.000000     2068.000000   19833.000000          25.000000

# %%
df1 = df.groupby('Gender')
df1['Age'].describe()
# Out:
#         count       mean       std   min   25%   50%    75%   max
# Gender
# Female  150.0  37.140000  8.656014  18.0  31.0  36.0  44.75  58.0
# Male    262.0  36.267176  8.232563  20.0  30.0  35.0  41.75  60.0

# %%
df2 = df.groupby('EducationField')
df2['Age'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-489266eb1979> in <cell line: 1>()
# ----> 1 df2 = df.groupby('EducationField')
#       2 df2['Age'].describe()
#
# NameError: name 'df' is not defined

# %%
df2 = df.groupby('JobRole')
df2['Age'].describe()
# Out:
#                            count       mean       std   min    25%   50%  \
# JobRole
# Healthcare Representative   43.0  39.488372  8.227052  24.0  33.50  39.0
# Human Resources             22.0  33.727273  7.011432  24.0  28.25  33.0
# Laboratory Technician       71.0  34.140845  7.796145  22.0  28.50  34.0
# Manager                     23.0  47.130435  6.750787  32.0  42.00  47.0
# Manufacturing Director      38.0  37.973684  6.937898  25.0  34.25  38.0
# Research Director           18.0  45.277778  6.524213  31.0  42.25  45.5
# Research Scientist          78.0  33.974359  8.001582  18.0  29.00  32.5
# Sales Executive             94.0  36.840426  6.625632  25.0  32.00  35.0
# Sales Representative        25.0  30.160000  8.537564  18.0  23.00  29.0
#
#                             75%   max
# JobRole
# Healthcare Representative  45.0  60.0
# Human Resources            38.0  45.0
# Laboratory Technician      39.0  56.0
# Manager                    52.5  58.0
# ...

# %%
df3 = pd.read_csv('/content/Iris.csv')

# %%
df3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df4 = df3.groupby('Species')
df4.describe()
# Out:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...
